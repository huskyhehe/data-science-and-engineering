# %% [markdown]
# What is pandas ?
#
# pandas is an open source python library that contains data structures and tools for dealing with data (http://pandas.pydata.org/).
#
# Why pandas ?
#
# pandas is very intuitive and used a dataframe theme to handle data.
# A bit like your all popular excel spreadsheet, but many, many times more powerful ad flexible.
#
# Which dataset example?
#
# The old Titanic dataset which consists of details of the majority of passengers who travelled on RMS Titanic.
#
# ![Funny_titanic.jpg](attachment:Funny_titanic.jpg)
#
# "The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class"
#
# Can you believe it ? The first class passengers escaping the sinking while the poor third class had to sink with it !
#
#
#
# source: kaggle.com

# %%
#Import pandas...aka, why reinvent the wheel when you can steal it ?

import pandas as pd

# %% [markdown]
# # Who's ready to investigate the titanic disaster?

# %%
'''Where is our jupyter notebook living in the computer ?'''
# %pwd
# Out:
# '/Users/ram/Desktop/DAMG6106_AKA_INFO6101'

# %%
'''Let's start by taking a look at how much do we actually know !
Read in the data'''

my_df = pd.read_csv("/Users/ram/Desktop/DAMG6106_AKA_INFO6101/Titanic.csv")

'''Then take a look at its rows and columns,

Shape is a fancy way of saying it'''
my_df.shape
# Out:
# (891, 12)

# %%
'''What if the data came packaged as say another kind of file ?
Different file types that can be read in (demo), 
sql, tables, json, etc'''

#pd.
# Out:
# 'What if the data came packaged as say another kind of file ?\nDifferent file types that can be read in (demo), \nsql, tables, json, etc'

# %%
# Are you ready to take a sneak peak at the passengers ?
#The way we do this is use the head of the...well, snake !

my_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
'''What kind of details do we have ?'''

my_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Big deal ! Is the last few rows of data the same ?
#Hint: the snake has a head and a...what?

my_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#During your investigation, you may need to select some things
#while filtering out other columns ! How do we do this ?

my_df_sel = my_df[["Name","Age"]]

# %%
'''Never trust Ram ! trust the data, take a look...'''

my_df_sel.columns
# Out:
# Index(['Name', 'Age'], dtype='object')

# %%
#Ram, this is great for this dataset !
#What if we din't know the solumn names & want to pick columns by
#their posiiton ?How do we, select rows & columns ?

my_df.iloc[0:4,5:7]
# Out:
#     Age  SibSp
# 0  22.0      1
# 1  38.0      1
# 2  26.0      0
# 3  35.0      1

# %%
#Ram, how do I select certain rows of data by the row number ?

my_df.iloc[10:15]
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 10  female   4.0      1      1    PP 9549  16.7000    G6        S
# 11  female  58.0      0      0     113783  26.5500  C103        S
# 12    male  20.0      0      0  A/5. 2151   8.0500   NaN        S
# 13    male  39.0      1      5     347082  31.2750   NaN        S
# 14  female  14.0      0      0     350406   7.8542   NaN        S

# %%
#Ram, now how do I select certain columns of data by the row number ?

my_df.iloc[: ,5:8]
# Out:
#       Age  SibSp  Parch
# 0    22.0      1      0
# 1    38.0      1      0
# 2    26.0      0      0
# 3    35.0      1      0
# 4    35.0      0      0
# ..    ...    ...    ...
# 886  27.0      0      0
# 887  19.0      0      0
# 888   NaN      1      2
# 889  26.0      0      0
# 890  32.0      0      0
#
# [891 rows x 3 columns]

# %%
#Ram, very clever (so you think!)
#Now, how do we select rows & columns at the same time ?

my_df.iloc[0:4,5:7]
# Out:
#     Age  SibSp
# 0  22.0      1
# 1  38.0      1
# 2  26.0      0
# 3  35.0      1

# %%
# Ram, I changed ny mind. I only am interested in all the women who
#travelled on the Titanic. 
#Hint: Select specific rows that match a given condition

select_df = my_df[my_df["Sex"] == "female"]
print(select_df.shape)
select_df.head(3)

#At least 312 women travelled on board the Titanic...
# Out:
# (314, 12)
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
'''From which points did they get on that wretched ship ?'''

my_df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
'''Now, I want to sort the data by name of passenger, then by their age.
I can do this using the sort function in excel, is python even
a match to excel ?Humpf!'''

sorted_df = my_df.sort_values(by = ["Name","Age"],inplace = False)
sorted_df.head()
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
#
#         Sex   Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 845    male  42.0      0      0  C.A. 5547   7.55   NaN        S
# 746    male  16.0      1      1  C.A. 2673  20.25   NaN        S
# 279  female  35.0      1      1  C.A. 2673  20.25   NaN        S
# 308    male  30.0      1      0  P/PP 3381  24.00   NaN        C
# 874  female  28.0      1      0  P/PP 3381  24.00   NaN        C

# %%
# Now I want to mess the datafram up ! I want rows to become columns and
# vice versa...Hint: this is called transposing a dataframe.

my_df_T = my_df.T
my_df_T.head()
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
#
#                                 2    \
# PassengerId                       3
# Survived                          1
# Pclass                            3
# Name         Heikkinen, Miss. Laina
# Sex                          female
#
#                                                       3    \
# PassengerId                                             4
# ...

# %%
'''As before, never trust Ram !'''
my_df_T.shape
# Out:
# (12, 891)

# %% [markdown]
# # Drill Time !

# %% [markdown]
# From this dataset, how many passengers were male ?

# %% [markdown]
# From this dataset, how many passengers were female ?

# %% [markdown]
# How many male passengers survived the sinking ? (0 = No, 1 = Yes)

# %% [markdown]
# How many female passengers survived the sinking ?

# %% [markdown]
# How many people above age 25 were in the ship at the time of sinking ?

# %% [markdown]
# How many females below age 50 survived the sinking ?

# %% [markdown]
# How many people who travelled Pclass 1 survived ?

# %% [markdown]
# How many people who travelled Pclass 3 survived ?

# %% [markdown]
# Can you make a dataframe of all passengers sorted by their age ?

# %% [markdown]
# How many people below age 20 survived the sinking ?
